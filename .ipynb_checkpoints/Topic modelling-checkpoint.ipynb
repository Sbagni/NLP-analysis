# %%
import gensim
import gensim.corpora as corpora
from gensim.corpora import Dictionary
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel

from pprint import pprint

#import spacy

import pickle
import re 
#from pyLDAvis import pyLDAvis
#import pyLDAvis.gensim

import matplotlib.pyplot as plt 
import pandas as pd
import pandas as pd
news= pd.read_csv("text-data.csv")

# %%
news.head()
# Out:
#    Record ID Description                                              Text2
# 0          1      Impact  To meet someone with the knowledge and passion...
# 1          2      Impact  To meet someone with the knowledge and passion...
# 2          3      Impact  Anake Kū is my Kumu. I have looked up to her a...
# 3          4      Impact    I enjoyed the keynote because it was informa...
# 4          5      Impact   That Ku is a force in and of herself and chan...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop=set(stopwords.words('english'))
corpus=[]
new= news['Text2'].str.split()
new=new.values.tolist()
corpus=[word for i in new for word in i]

from collections import defaultdict
dic=defaultdict(int)
for word in corpus:
    if word in stop:
        dic[word]+=1
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sumat\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus
# Out:
# ['To',
#  'meet',
#  'someone',
#  'with',
#  'the',
#  'knowledge',
#  'and',
#  'passion',
#  'for',
#  'Hawaii',
#  'is',
#  'inspirational',
#  'and',
#  'gave',
#  'me',
#  'a',
#  'deeper',
#  'love',
#  'for',
#  'our',
#  'culture',
#  'and',
#  'islands.',
#  'The',
#  'reminder',
#  'about',
#  'the',
#  'history',
#  'of',
#  'literacy',
#  'in',
#  'Hawaii',
#  'and',
#  'the',
#  'sizable',
#  'kuleana',
#  'we',
#  'have',
#  'to',
#  'get',
#  'us',
#  'back',
#  'there.',
#  'To',
#  'meet',
#  'someone',
#  'with',
#  'the',
#  'knowledge',
#  'and',
#  'passion',
#  'for',
#  'Hawaii',
#  'is',
#  'inspirational',
#  'and',
#  'gave',
#  'me',
#  'a',
#  'deeper',
#  'love',
#  'for',
#  'our',
#  'culture',
#  'and',
#  'islands.',
#  'The',
#  'reminder',
#  'about',
#  'the',
#  'history',
#  'of',
#  'literacy',
#  'in',
#  'Hawaii',
#  'and',
#  'the',
#  'sizable',
#  'kuleana',
#  'we',
#  'have',
#  'to',
#  'get',
#  'us',
#  'back',
#  'there.',
#  'Anake',
#  'Kū',
#  'is',
#  'my',
#  'Kumu.',
#  'I',
#  'have',
#  'looked',
#  'up',
#  'to',
#  'her',
#  'and',
#  'have',
#  'followed',
#  'along',
#  'in',
#  'her',
#  'mission',
#  'and',
#  'in',
#  'her',
#  'vision',
#  'over',
#  'the',
#  'years.',
#  'She',
#  'had',
#  'a',
#  'dream,',
#  'that',
#  'came',
#  'true.',
#  'I',
#  'was',
#  'a',
#  'part',
#  'of',
#  'that',
#  'dream,',
#  'and',
#  'it',
#  'is',
#  'now',
#  'my',
#  'kuleana',
#  'to',
#  'keep',
#  'that',
#  'ream',
#  'thriving.',
#  'As',
#  'always,',
#  'I',
#  'am',
#  'memorized',
#  'by',
#  'her',
#  'words,',
#  'and',
#  'am',
#  'honored',
#  'and',
#  'privileged',
#  'to',
#  'know',
#  'her.',
#  'She',
#  'is',
#  'and',
#  'will',
#  'always',
#  'be',
#  'a',
#  'big',
#  'part',
#  'of',
#  'my',
#  'drive',
#  'in',
#  'education.',
#  'Mahalo',
#  'piha',
#  'e',
#  "'anake",
#  'Kū,',
#  'nui',
#  'me',
#  'ke',
#  'aloha',
#  'iā',
#  "'oe",
#  'I',
#  'enjoyed',
#  'the',
#  'keynote',
#  'because',
#  'it',
#  'was',
#  'informational',
#  'and',
#  'felt',
#  'really',
#  'welcoming.',
#  'That',
#  'Ku',
#  'is',
#  'a',
#  'force',
#  'in',
#  'and',
#  'of',
#  'herself',
#  'and',
#  'changes',
#  'and',
#  'adapts',
#  'with',
#  'the',
#  'times',
#  'and',
#  'circumstances.',
#  'I',
#  'know',
#  'she',
#  'has',
#  'a',
#  'strong',
#  'support',
#  'system.',
#  'I',
#  'have',
#  'great',
#  'aloha',
#  'for',
#  'them',
#  'all.',
#  'Kū',
#  'Kahakalau',
#  'shared',
#  'her',
#  'manaʻo',
#  'of',
#  'where',
#  'she',
#  'was',
#  'born',
#  'and',
#  'raised',
#  'and',
#  'her',
#  'ability',
#  'to',
#  'speak',
#  'several',
#  'languages',
#  'and',
#  'about',
#  'learning',
#  'the',
#  'Hawaiian',
#  'Language',
#  'and',
#  'culture',
#  'of',
#  'Hawaiʻi.',
#  'Hearing',
#  'her',
#  'speak',
#  'of',
#  'her',
#  'life',
#  'in',
#  'Waipiʻo',
#  'and',
#  'raising',
#  'her',
#  'family',
#  'there',
#  'was',
#  'very',
#  'interesting.',
#  'She',
#  'is',
#  'very',
#  'intelligent',
#  'and',
#  'very',
#  'educated',
#  'in',
#  'so',
#  'many',
#  'fields',
#  'and',
#  'have',
#  'a',
#  'lot',
#  'of',
#  'manaʻo',
#  'to',
#  'share',
#  'with',
#  'our',
#  'Hawaiian',
#  'community.',
#  'I',
#  'loved',
#  'her',
#  'energy.',
#  'Good',
#  'start',
#  'to',
#  'the',
#  'day!',
#  'The',
#  'ongoing',
#  'dedication',
#  'to',
#  'revive',
#  'ʻōlelo',
#  'Hawaii',
#  'and',
#  'Hawaiian',
#  'culture',
#  'based',
#  'learning.',
#  'The',
#  'love',
#  'she',
#  'demonstrates',
#  'for',
#  'her',
#  'people',
#  'and',
#  'future',
#  'generations.',
#  'The',
#  'mana,',
#  'energy,',
#  'love,',
#  'excitement,',
#  'care,',
#  'emanating',
#  'from',
#  'this',
#  'presenter.',
#  'Kū',
#  'Kahakalau',
#  'is',
#  'an',
#  'inspiring',
#  'speaker,',
#  'she',
#  'set',
#  'a',
#  'wonderful',
#  'tone',
#  'for',
#  'the',
#  'conference.',
#  'Very',
#  'interesting',
#  'concept,',
#  '"institutionalized',
#  'racism"',
#  'she',
#  'brought',
#  'up.',
#  'Reinforcment',
#  'that',
#  'as',
#  'a',
#  'community,',
#  'we',
#  'have',
#  'the',
#  'resources',
#  'and',
#  'do',
#  'not',
#  'need',
#  '"outside"',
#  'influences',
#  'to',
#  'show',
#  'our',
#  'community',
#  'how',
#  'to',
#  'interact',
#  'with',
#  'our',
#  'community',
#  'How',
#  'passionate',
#  'we',
#  'are',
#  'is',
#  'reflected',
#  'in',
#  'what',
#  'we',
#  'convey.',
#  'Some',
#  'new',
#  'historical',
#  'facts',
#  'that',
#  'I',
#  'learned.',
#  'I',
#  'loved',
#  'how',
#  'she',
#  'helped',
#  'support',
#  "'olelo",
#  "Hawai'i",
#  'in',
#  'the',
#  'school',
#  'systems',
#  'and',
#  'I',
#  'felt',
#  'a',
#  'sense',
#  'of',
#  'pride',
#  'as',
#  'she',
#  'spoke',
#  'about',
#  'our',
#  'Hawaiian',
#  'Kupuna/ancestors.',
#  'What',
#  'impacted',
#  'me',
#  'the',
#  'most',
#  'from',
#  'this',
#  'presentation',
#  'was',
#  'learning',
#  'that',
#  'our',
#  'ancestors',
#  'learned,',
#  'taught,',
#  'practiced,',
#  'and',
#  'handed',
#  'down',
#  'what',
#  'people',
#  'now',
#  'and',
#  'within',
#  'the',
#  'last',
#  'few',
#  'decades',
#  'are',
#  'realizing',
#  'are',
#  'the',
#  'best',
#  'way',
#  'to',
#  'teach',
#  'and',
#  'educate',
#  'native',
#  'Hawaiians.',
#  'She',
#  'is',
#  'so',
#  'knowledgeable.',
#  'I',
#  'enjoy',
#  'learning',
#  'from',
#  'Dr.',
#  'Kahakalau.',
#  'In',
#  'addition',
#  'to',
#  'her',
#  'wealth',
#  'of',
#  'knowledge',
#  'on',
#  'indigenous',
#  'education',
#  'and',
#  'language,',
#  'I',
#  'really',
#  'appreciate',
#  'how',
#  'she',
#  'consistently',
#  'incorporated',
#  'ʻohana',
#  'images',
#  'and',
#  'examples',
#  'throughout',
#  'her',
#  'presentation.',
#  'What',
#  'impacted',
#  'me',
#  'the',
#  'most',
#  'was',
#  'her',
#  'delivery',
#  'and',
#  'how',
#  'she',
#  'demonstrated',
#  'her',
#  'love',
#  'for',
#  'education',
#  'and',
#  'foundation',
#  'of',
#  'aloha',
#  'as',
#  'a',
#  'lifestyle',
#  'and',
#  'not',
#  'a',
#  'career',
#  'or',
#  'chore',
#  'for',
#  'that',
#  'matter.',
#  'Teach',
#  'Hawaii-centric!',
#  'Rigor!',
#  'Connection',
#  'to',
#  'aina',
#  'and',
#  'kupuna!',
#  'Great',
#  'presenter.',
#  'Joining',
#  'together',
#  'on',
#  'both',
#  'sides',
#  'of',
#  'the',
#  'fence.',
#  'The',
#  'systematic',
#  'racism',
#  'that',
#  'has',
#  'happened',
#  'and',
#  'continues',
#  'to',
#  'happen',
#  'in',
#  'Hawaii',
#  'to',
#  'its',
#  'people.',
#  'It',
#  'gave',
#  'me',
#  'a',
#  'some',
#  'of',
#  'the',
#  'history',
#  'of',
#  'the',
#  'program',
#  'and',
#  'having',
#  'a',
#  'live',
#  'reaction',
#  'during',
#  'the',
#  'presentation',
#  'showed',
#  'where',
#  'I',
#  'was',
#  'in',
#  'my',
#  'thinking',
#  'as',
#  'topics',
#  'came',
#  'up.',
#  'The',
#  'shared',
#  'ideal',
#  'of',
#  'the',
#  'importance',
#  'of',
#  'ʻŌlelo',
#  'Hawaiʻi,',
#  'the',
#  'connection',
#  'of',
#  'Hawaiian',
#  'values,',
#  'morals,',
#  'and',
#  'traditions',
#  'and',
#  'itʻs',
#  'value',
#  'to',
#  'all',
#  'today.',
#  'The',
#  'information',
#  'shared',
#  'and',
#  'how',
#  'it',
#  'was',
#  'shedding',
#  'light',
#  'on',
#  'how',
#  'the',
#  'DOE',
#  'lacks',
#  'cultural',
#  'integration',
#  'in',
#  'the',
#  'system',
#  'as',
#  'a',
#  'whole.',
#  'The',
#  'light',
#  'shed',
#  'on',
#  'the',
#  'DOE',
#  'and',
#  'the',
#  'lack',
#  'of',
#  'culture',
#  'in',
#  'schools.',
#  'Data',
#  'confirms',
#  'that',
#  'the',
#  'lower',
#  'education',
#  'achievement',
#  'of',
#  'Native',
#  'Hawaiians',
#  'is',
#  'a',
#  'reflection',
#  'of',
#  'the',
#  'incompatibility',
#  'of',
#  'the',
#  'current',
#  'education',
#  'system',
#  'with',
#  'our',
#  'native',
#  'Hawaiian',
#  'cultural',
#  'propensities',
#  'and',
#  'preferences.',
#  'Children',
#  'are',
#  'the',
#  'evidence,',
#  'not',
#  'the',
#  'crime.',
#  'The',
#  'fun,',
#  'interactive',
#  'style',
#  'kept',
#  'attendees',
#  'on',
#  'their',
#  'toes',
#  'and',
#  'having',
#  'to',
#  'actually',
#  'evaluate',
#  'their',
#  'opinions.',
#  'How',
#  'educationally',
#  'advanced',
#  'Hawaii',
#  'was',
#  'in',
#  'the',
#  'past.',
#  'Also',
#  'PEAR',
#  'DECK',
#  'was',
#  'amazing',
#  'and',
#  'I',
#  'downloaded',
#  'it',
#  'immediately.',
#  'love',
#  'her',
#  'oli',
#  'aloha',
#  'and',
#  'oli',
#  'mahalo',
#  'very',
#  'simple',
#  'and',
#  'impactful.',
#  '<3',
#  'Her',
#  'passion',
#  'and',
#  'knowledge.',
#  'Dr.',
#  'Ku',
#  'is',
#  'amazing.',
#  'Her',
#  'presentation',
#  'about',
#  'history',
#  'and',
#  'knowledge',
#  'blew',
#  'me',
#  'away.',
#  'Indigenous',
#  'teaching',
#  'is',
#  'awesome!',
#  'The',
#  'information',
#  'on',
#  'historical',
#  'education',
#  'in',
#  'Hawaiʻi',
#  'and',
#  'how',
#  'we',
#  'should',
#  'move',
#  'forward',
#  'with',
#  'HCBE.',
#  'The',
#  'information',
#  'provided',
#  'was',
#  'based',
#  'on',
#  'research',
#  'and',
#  'applicable',
#  'to',
#  'both',
#  'formal',
#  'and',
#  'informal',
#  'education',
#  'settings.',
#  'The',
#  'way',
#  'Kū',
#  'Kahakalau',
#  'shared',
#  'her',
#  'ʻike',
#  'and',
#  'created',
#  'an',
#  'opportunity',
#  'for',
#  'everyone',
#  'to',
#  'participate',
#  'and',
#  'be',
#  'involved',
#  'and',
#  'not',
#  'just',
#  'listen.',
#  'Ku',
#  'was',
#  'very',
#  'inspirational',
#  'and',
#  'I',
#  'loved',
#  'the',
#  'way',
#  'she',
#  'involved',
#  'us',
#  '(the',
#  'audience)',
#  'in',
#  'her',
#  'presentation.',
#  'Be',
#  'the',
#  'aloha',
#  'I',
#  'want',
#  'to',
#  'see',
#  'in',
#  'the',
#  'world.',
#  'I',
#  'love',
#  'that',
#  'she',
#  'asked',
#  'us',
#  'questions',
#  'to',
#  'keep',
#  'us',
#  'focus.',
#  'Her',
#  'presentation',
#  'overall',
#  'was',
#  'excellent.',
#  'It',
#  'was',
#  'very',
#  'inspirational',
#  'full',
#  'of',
#  'facts/data',
#  'to',
#  'support',
#  'her',
#  'speech.',
#  'How',
#  'we',
#  'as',
#  'Hawaiians',
#  'should',
#  'make',
#  'it',
#  'our',
#  'kuleana',
#  'to',
#  'not',
#  'be',
#  'afraid',
#  'to',
#  'voice',
#  'our',
#  'feelings',
#  'and',
#  'rights',
#  'that',
#  'were',
#  'already',
#  'ours',
#  'to',
#  'begin',
#  'with.',
#  "It's",
#  'a',
#  'shame',
#  'how',
#  'colonialism',
#  'has',
#  'effected',
#  'the',
#  'whole',
#  'world.',
#  'But',
#  'I',
#  'case',
#  "it's",
#  'the',
#  'natural',
#  'process',
#  'of',
#  'things.',
#  'The',
#  'passion',
#  'Ku',
#  'continues',
#  'has',
#  'for',
#  'Hawaiian',
#  'education.',
#  'The',
#  'Hawaiian',
#  'History',
#  'of',
#  'our',
#  'Education.',
#  'The',
#  'evolution',
#  '&',
#  'progress',
#  'made',
#  'to',
#  'get',
#  'back',
#  'to',
#  'the',
#  'holistic',
#  'way',
#  'to',
#  'educate',
#  'vs.',
#  'the',
#  'western',
#  'way.',
#  'We',
#  'can',
#  'undo',
#  'the',
#  'harm',
#  'done',
#  'by',
#  'generations',
#  'of',
#  'Western',
#  'ways',
#  'via',
#  'the',
#  'pedagogy',
#  'of',
#  'aloha.',
#  'What',
#  'an',
#  'amazing',
#  'presentation.',
#  'She',
#  'set',
#  'the',
#  'tone',
#  'for',
#  'the',
#  'entire',
#  'day.',
#  'Haumāna',
#  'learn',
#  'through',
#  'play.',
#  'We',
#  'have',
#  'to',
#  'remember',
#  'that.',
#  'to',
#  'learn',
#  'that',
#  'education',
#  'can',
#  'be',
#  'reformed',
#  'for',
#  'our',
#  'hawaiian',
#  'keiki',
#  'She',
#  'shared',
#  'so',
#  'much',
#  'valuable',
#  'manaʻo!',
#  'I',
#  'liked',
#  'the',
#  'Mea',
#  'hanohano',
#  'Lūʻau',
#  'model,',
#  'the',
#  'hawaiian',
#  ...]

# %%
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.tokenize import word_tokenize
def _preprocess_text(text):
    corpus=[]
    stem=PorterStemmer()
    lem=WordNetLemmatizer()
    for news in text:
        words=[w for w in word_tokenize(news) if (w not in stop)]
        words=[lem.lemmatize(w) for w in words if len(w)>2]
        corpus.append(words)
        return corpus
    corpus=_preprocess_text(text)

# %%
corpus=_preprocess_text(news['Text2'])

# %%
corpus
# Out:
# [['meet',
#   'someone',
#   'knowledge',
#   'passion',
#   'Hawaii',
#   'inspirational',
#   'gave',
#   'deeper',
#   'love',
#   'culture',
#   'island',
#   'The',
#   'reminder',
#   'history',
#   'literacy',
#   'Hawaii',
#   'sizable',
#   'kuleana',
#   'get',
#   'back']]

# %%
import gensim
from gensim import corpora
from gensim.corpora import Dictionary
from gensim import models
from gensim.models import LdaModel
from gensim.models import TfidfModel
#from gensim.models import Doc2bowModel
#from gensim.models.wrappers import LdaMallet

# %%
dic= gensim.corpora.Dictionary(corpus)
bow_corpus = [dic.doc2bow(doc) for doc in corpus]

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 4, 
                                   id2word = dic,                                    
                                   passes = 10,
                                   workers = 2)
lda_model.show_topics()
# Out:
# [(0,
#   '0.053*"inspirational" + 0.053*"literacy" + 0.053*"The" + 0.053*"get" + 0.053*"meet" + 0.053*"sizable" + 0.053*"deeper" + 0.053*"kuleana" + 0.053*"gave" + 0.053*"back"'),
#  (1,
#   '0.091*"Hawaii" + 0.051*"reminder" + 0.051*"culture" + 0.051*"history" + 0.051*"someone" + 0.051*"meet" + 0.051*"knowledge" + 0.051*"gave" + 0.051*"passion" + 0.051*"island"'),
#  (2,
#   '0.053*"inspirational" + 0.053*"kuleana" + 0.053*"Hawaii" + 0.053*"get" + 0.053*"sizable" + 0.053*"The" + 0.053*"back" + 0.053*"literacy" + 0.053*"deeper" + 0.053*"love"'),
#  (3,
#   '0.053*"inspirational" + 0.053*"kuleana" + 0.053*"get" + 0.053*"sizable" + 0.053*"deeper" + 0.053*"meet" + 0.053*"knowledge" + 0.053*"literacy" + 0.053*"back" + 0.053*"love"')]

# %%
import numpy as np
import nltk
from nltk.corpus import stopwords
import gensim
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.tokenize import word_tokenize
from pyLDAvis import pyLDAvis


def get_lda_objects(text):
    nltk.download('stopwords')    
    stop=set(stopwords.words('english'))

    
    def _preprocess_text(text):
        corpus=[]
        stem=PorterStemmer()
        lem=WordNetLemmatizer()
        for news in text:
            words=[w for w in word_tokenize(news) if (w not in stop)]

            words=[lem.lemmatize(w) for w in words if len(w)>2]

            corpus.append(words)
        return corpus
    
    corpus=_preprocess_text(text)
    
    dic=gensim.corpora.Dictionary(corpus)
    bow_corpus = [dic.doc2bow(doc) for doc in corpus]
    
    lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 4, 
                                   id2word = dic,                                    
                                   passes = 10,
                                   workers = 2)
    
    return lda_model, bow_corpus, dic

def plot_lda_vis(lda_model, bow_corpus, dic):
    pyLDAvis.enable_notebook()
    vis = pyLDAvis.gensim.prepare(lda_model, bow_corpus, dic)
    return vis
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-56-1d32b201d288> in <module>
#       5 from nltk.stem import WordNetLemmatizer,PorterStemmer
#       6 from nltk.tokenize import word_tokenize
# ----> 7 from pyLDAvis import pyLDAvis
#       8
#       9
#
# ~\Desktop\Catchfire Data Visualisation Project\pyLDAvis\pyLDAvis\__init__.py in <module>
#      42 __version__ = "3.3.1"
#      43
# ---> 44 from pyLDAvis._display import *
#      45 from pyLDAvis._prepare import prepare, js_PCoA, PreparedData
#
# ModuleNotFoundError: No module named 'pyLDAvis._display'

# %%
lda_model, bow_corpus, dic = get_lda_objects(news['Text2'])

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 4, 
                                   id2word = dic,                                    
                                   passes = 10,
                                   workers = 2)
lda_model.show_topics()

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, bow_corpus, dic)
vis
