# %%
import re
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %matplotlib inline

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 100)

data = pd.read_csv("text-data.csv")

data.head()
# Out:
#    Record ID Description  \
# 0          1      Impact
# 1          2      Impact
# 2          3      Impact
# 3          4      Impact
# 4          5      Impact
#
#                                                                                                  Text2
# 0  To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 1  To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 2  Anake Kū is my Kumu. I have looked up to her and have followed along in her mission and in her v...
# 3                       I enjoyed the keynote because it was informational and felt really welcoming.
# 4   That Ku is a force in and of herself and changes and adapts with the times and circumstances. I...

# %%
data_cleaned = pd.read_csv("text-data.csv")
data_cleaned.head()
# Out:
#    Record ID Description  \
# 0          1      Impact
# 1          2      Impact
# 2          3      Impact
# 3          4      Impact
# 4          5      Impact
#
#                                                                                                  Text2
# 0  To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 1  To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 2  Anake Kū is my Kumu. I have looked up to her and have followed along in her mission and in her v...
# 3                       I enjoyed the keynote because it was informational and felt really welcoming.
# 4   That Ku is a force in and of herself and changes and adapts with the times and circumstances. I...

# %%
import string

# %%
def remove_punct(text):
    text_nopunct = "".join([char for char in text if char not in string.punctuation])
    return text_nopunct

data['body_text_clean'] = data['Text2'].apply(lambda x: remove_punct(x))

data.head()
# Out:
#    Record ID Description  \
# 0          1      Impact
# 1          2      Impact
# 2          3      Impact
# 3          4      Impact
# 4          5      Impact
#
#                                                                                                  Text2  \
# 0  To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 1  To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 2  Anake Kū is my Kumu. I have looked up to her and have followed along in her mission and in her v...
# 3                       I enjoyed the keynote because it was informational and felt really welcoming.
# 4   That Ku is a force in and of herself and changes and adapts with the times and circumstances. I...
#
#                                                                                        body_text_clean
# 0  To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 1  To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 2  Anake Kū is my Kumu I have looked up to her and have followed along in her mission and in her vi...
# 3                        I enjoyed the keynote because it was informational and felt really welcoming
# 4   That Ku is a force in and of herself and changes and adapts with the times and circumstances I ...

# %%
import re

def tokenize(text):
    tokens = re.split('\W+', text)
    return tokens

data['body_text_tokenized'] = data['body_text_clean'].apply(lambda x: tokenize(x.lower()))

data.head()
# Out:
#    Record ID Description  \
# 0          1      Impact
# 1          2      Impact
# 2          3      Impact
# 3          4      Impact
# 4          5      Impact
#
#                                                                                                  Text2  \
# 0  To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 1  To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 2  Anake Kū is my Kumu. I have looked up to her and have followed along in her mission and in her v...
# 3                       I enjoyed the keynote because it was informational and felt really welcoming.
# 4   That Ku is a force in and of herself and changes and adapts with the times and circumstances. I...
#
#                                                                                        body_text_clean  \
# 0  To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 1  To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 2  Anake Kū is my Kumu I have looked up to her and have followed along in her mission and in her vi...
# 3                        I enjoyed the keynote because it was informational and felt really welcoming
# 4   That Ku is a force in and of herself and changes and adapts with the times and circumstances I ...
#
#                                                                                    body_text_tokenized
# 0  [to, meet, someone, with, the, knowledge, and, passion, for, hawaii, is, inspirational, and, gav...
# 1  [to, meet, someone, with, the, knowledge, and, passion, for, hawaii, is, inspirational, and, gav...
# 2  [anake, kū, is, my, kumu, i, have, looked, up, to, her, and, have, followed, along, in, her, mis...
# 3        [, i, enjoyed, the, keynote, because, it, was, informational, and, felt, really, welcoming, ]
# 4  [, that, ku, is, a, force, in, and, of, herself, and, changes, and, adapts, with, the, times, an...

# %%
#stemming
from nltk.stem.porter import *
stemmer = PorterStemmer()

tokenized_text = data['body_text_tokenized'].apply(lambda x: [stemmer.stem(i) for i in x]) 
tokenized_text.head()
# Out:
# 0    [to, meet, someon, with, the, knowledg, and, passion, for, hawaii, is, inspir, and, gave, me, a,...
# 1    [to, meet, someon, with, the, knowledg, and, passion, for, hawaii, is, inspir, and, gave, me, a,...
# 2    [anak, kū, is, my, kumu, i, have, look, up, to, her, and, have, follow, along, in, her, mission,...
# 3                         [, i, enjoy, the, keynot, becaus, it, wa, inform, and, felt, realli, welcom, ]
# 4    [, that, ku, is, a, forc, in, and, of, herself, and, chang, and, adapt, with, the, time, and, ci...
# Name: body_text_tokenized, dtype: object

# %%
for i in range(len(tokenized_text)):
    tokenized_text[i] = ' '.join(tokenized_text[i])

data['body_text_tokenized'] = tokenized_text

# %%
#most common words used
all_words = ' '.join([text for text in data['Text2'] ])
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.savefig("Wordcloud.png")
plt.show()

# %%
from textblob import TextBlob
TextBlob("I hate nlp").sentiment
# Out:
# Sentiment(polarity=-0.8, subjectivity=0.9)

# %%
pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity

data['polarity'] = data['body_text_clean'].apply(pol)
data['subjectivity'] = data['body_text_clean'].apply(sub)
data
# Out:
#      Record ID Description  \
# 0            1      Impact
# 1            2      Impact
# 2            3      Impact
# 3            4      Impact
# 4            5      Impact
# 5            6      Impact
# 6            7      Impact
# 7            8      Impact
# 8            9      Impact
# 9           10      Impact
# 10          11      Impact
# 11          12      Impact
# 12          13      Impact
# 13          14      Impact
# 14          15      Impact
# 15          16      Impact
# 16          17      Impact
# 17          18      Impact
# 18          19      Impact
# 19          20      Impact
# 20          21      Impact
# 21          22      Impact
# 22          23      Impact
# 23          24      Impact
# 24          26      Impact
# 25          27      Impact
# 26          28      Impact
# 27          29      Impact
# 28          30      Impact
# 29          31      Impact
# ..         ...         ...
# 136        148      Impact
# 137        149      Impact
# 138        150      Impact
# 139        151      Impact
# 140        152      Impact
# 141        153      Impact
# 142        154      Impact
# 143        155      Impact
# 144        156      Impact
# 145        157      Impact
# 146        158      Impact
# 147        159      Impact
# 148        160      Impact
# 149        161      Impact
# 150        162      Impact
# 151        163      Impact
# 152        164      Impact
# 153        165      Impact
# 154        166      Impact
# 155        167      Impact
# 156        168      Impact
# 157        169      Impact
# 158        170      Impact
# 159        171      Impact
# 160        172      Impact
# 161        173      Impact
# 162        174      Impact
# 163        175      Impact
# 164        176      Impact
# 165        177      Impact
#
#                                                                                                    Text2  \
# 0    To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
#
# 155   I will start to change the way I refer to "cultural vs. academic" and will now use the words "t...
# 156                                                                The importance of Hawaiian Education
# 157                                                                                         Rigor + Fun
# 158                                                             aloha ʻāina is a truly remarkable cycle
# 159                                  Kū's manaʻo, sharing genealogies and the interaction on the slides
# 160                                                                                  The aloha and mana
# 161                                                           Everything she spoke on was so impactful.
# 162                        It reminded me that we all are able to impact using our individual strengths
# 163    The insights into the way things were done long ago are being overlooked by mainstream education
# 164                                                                          Not letting the ship sink!
# 165  Dr. Kahakalau allows her audience "to play along", thus making the presentation relevant. She al...
#
#                                                                                          body_text_clean  \
# 0    To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 1    To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 2    Anake Kū is my Kumu I have looked up to her and have followed along in her mission and in her vi...
# 3                          I enjoyed the keynote because it was informational and felt really welcoming
# 4     That Ku is a force in and of herself and changes and adapts with the times and circumstances I ...
# 5    Kū Kahakalau shared her manaʻo of where she was born and raised and her ability to speak several...
# 6                                                              I loved her energy Good start to the day
# 7    The ongoing dedication to revive ʻōlelo Hawaii and Hawaiian culture based learning The love she ...
# 8                                    The mana energy love excitement care emanating from this presenter
# 9    Kū Kahakalau is an inspiring speaker she set a wonderful tone for the conference Very interestin...
# 10   Reinforcment that as a community we have the resources and do not need outside influences to sho...
# 11                                                 How passionate we are is reflected in what we convey
# 12                                                             Some new historical facts that I learned
# 13   I loved how she helped support olelo Hawaii in the school systems and I felt a sense of pride as...
# 14    What impacted me the most from this presentation was learning that our ancestors learned taught...
# 15                                                                              She is so knowledgeable
# 16   I enjoy learning from Dr Kahakalau In addition to her wealth of knowledge on indigenous educatio...
# 17                                              Teach Hawaiicentric Rigor Connection to aina and kupuna
# 18                                                                                      Great presenter
# 19   Joining together on both sides of the fence The systematic racism that has happened and continue...
# 20    It gave me a some of the history of the program and having a live reaction during the presentat...
# 21   The shared ideal of the importance of ʻŌlelo Hawaiʻi the connection of Hawaiian values morals an...
# 22   Data confirms that the lower education achievement of Native Hawaiians is a reflection of the in...
# 23   The fun interactive style kept attendees on their toes and having to actually evaluate their opi...
# 24    How educationally advanced Hawaii was in the past Also PEAR DECK was amazing and I downloaded i...
# 25                                                                            Her passion and knowledge
# 26                           Dr Ku is amazing Her presentation about history and knowledge blew me away
# 27                                                                       Indigenous teaching is awesome
# 28    The information on historical education in Hawaiʻi and how we should move forward with HCBE The...
# 29    The way Kū Kahakalau shared her ʻike and created an opportunity for everyone to participate and...
# ..                                                                                                   ...
# 136                                                           So much knowledge Would love to hear more
# 137  Although I have taken classes with Anakē Kū I did not know how rare and prized the artistic abil...
# 138                                            Pedagogy of AlohaI wouldnt mind learning more about that
# 139   I love the quote that Anake Ku shared from Queen LiliuokalaniNever cease to act because you fea...
# 140                                                                         She spoke with such passion
# 141                                                                       I work at Kanu it is personal
# 142                                                                                          Everything
# 143                                              So knowledgeable so approachable so inclusive love her
# 144                To know that our kūpuna was already doing what the modern world is teaching nowadays
# 145                                                                                      Powerful manao
# 146                                                                                             Maikaʻi
# ..                                                                                                   ...
# 136                                                            so much knowledg would love to hear more
# 137  although i have taken class with anakē kū i did not know how rare and prize the artist abil are ...
# 138                                               pedagogi of alohai wouldnt mind learn more about that
# 139   i love the quot that anak ku share from queen liliuokalaninev ceas to act becaus you fear you m...
# 140                                                                         she spoke with such passion
# 141                                                                         i work at kanu it is person
# 142                                                                                             everyth
# 143                                                          so knowledg so approach so inclus love her
# 144                        to know that our kūpuna wa alreadi do what the modern world is teach nowaday
# 145                                                                                         power manao
# 146                                                                                             maikaʻi
# 147  she state when student feel safe when they feel like the peopl around them care for themthey wil...
# 148                                                                               hi reason for hi educ
# 149                                                                               all inform wa valuabl
# 150                                              veri inspir pedagogi of aloha relationship relev rigor
# 151  dr kahakalau use of from womb to tomb is so relev is so mani way it realli reson with me and go ...
# 152                                            hold ourselv account toward better the futur for hawaiian
# 153  hear that we were one of the lowest educ peopl we were told that we werenʻt smart and that wa du...
# 154  the factual histori lesson wa awesom i had some knowledg of thi histori but hi present wa great ...
# 155   i will start to chang the way i refer to cultur vs academ and will now use the word tradit and ...
# 156                                                                         the import of hawaiian educ
# 157                                                                                           rigor fun
# 158                                                                  aloha ʻāina is a truli remark cycl
# 159                                              kū manaʻo share genealog and the interact on the slide
# 160                                                                                  the aloha and mana
# 161                                                                   everyth she spoke on wa so impact
# 162                                it remind me that we all are abl to impact use our individu strength
# 163                the insight into the way thing were done long ago are be overlook by mainstream educ
# 164                                                                               not let the ship sink
# 165   dr kahakalau allow her audienc to play along thu make the present relev she alway uplift the lāhui
#
#      polarity  subjectivity
# 0    0.333333      0.533333
# 1    0.333333      0.533333
# 2    0.175000      0.375000
# 3    0.350000      0.450000
# 4    0.616667      0.741667
# 5    0.470000      0.490000
# 6    0.700000      0.700000
# 7    0.250000      0.362500
# 8    0.500000      0.600000
# 9    0.716667      0.883333
# 10   0.000000      0.050000
# 11  -0.050000      0.850000
# 12   0.068182      0.227273
# 13   0.700000      0.800000
# 14   0.228889      0.251111
# 15   0.000000      0.000000
# 16   0.370000      0.410000
# 17   0.000000      0.000000
# 18   0.800000      0.750000
# 19   0.000000      0.000000
# 20   0.136364      0.500000
# 21   0.400000      0.580000
# 22   0.050000      0.250000
# 23   0.150000      0.150000
# 24   0.250000      0.562857
# 25   0.000000      0.000000
# 26   0.600000      0.900000
# 27   1.000000      1.000000
# 28   0.000000      0.000000
# 29   0.675000      0.900000
# ..        ...           ...
# 136  0.400000      0.433333
# 137  0.297436      0.573077
# 138  0.500000      0.500000
# 139  0.000000      0.450000
# 140  0.000000      0.500000
# 141  0.000000      0.300000
# 142  0.000000      0.000000
# 143  0.500000      0.600000
# 144  0.200000      0.300000
# 145  0.300000      1.000000
# 146  0.000000      0.000000
# 147  0.203125      0.500000
# 148  0.000000      0.000000
# 149  0.000000      0.000000
# 150  0.650000      1.000000
# 151  0.366667      0.533333
# 152  0.000000      0.125000
# 153  0.029762      0.339286
# 154  0.396429      0.796429
# 155  0.161111      0.406944
# 156  0.000000      0.000000
# 157  0.300000      0.200000
# 158  0.750000      0.750000
# 159  0.000000      0.000000
# 160  0.000000      0.000000
# 161  0.000000      0.000000
# 162  0.250000      0.512500
# 163 -0.050000      0.400000
# 164  0.000000      0.000000
# 165  0.400000      0.900000
#
# [166 rows x 7 columns]

# %%
def getAnalysis(score):
        if score < 0:
            return 'Negative'
        elif score == 0:
            return 'Neutral'
        else:
            return 'Positive'

# %%
data ['TextBlob_Analysis'] = data ['polarity'].apply(getAnalysis )
data
# Out:
#      Record ID Description  \
# 0            1      Impact
# 1            2      Impact
# 2            3      Impact
# 3            4      Impact
# 4            5      Impact
# 5            6      Impact
# 6            7      Impact
# 7            8      Impact
# 8            9      Impact
# 9           10      Impact
# 10          11      Impact
# 11          12      Impact
# 12          13      Impact
# 13          14      Impact
# 14          15      Impact
# 15          16      Impact
# 16          17      Impact
# 17          18      Impact
# 18          19      Impact
# 19          20      Impact
# 20          21      Impact
# 21          22      Impact
# 22          23      Impact
# 23          24      Impact
# 24          26      Impact
# 25          27      Impact
# 26          28      Impact
# 27          29      Impact
# 28          30      Impact
# 29          31      Impact
# ..         ...         ...
# 136        148      Impact
# 137        149      Impact
# 138        150      Impact
# 139        151      Impact
# 140        152      Impact
# 141        153      Impact
# 142        154      Impact
# 143        155      Impact
# 144        156      Impact
# 145        157      Impact
# 146        158      Impact
# 147        159      Impact
# 148        160      Impact
# 149        161      Impact
# 150        162      Impact
# 151        163      Impact
# 152        164      Impact
# 153        165      Impact
# 154        166      Impact
# 155        167      Impact
# 156        168      Impact
# 157        169      Impact
# 158        170      Impact
# 159        171      Impact
# 160        172      Impact
# 161        173      Impact
# 162        174      Impact
# 163        175      Impact
# 164        176      Impact
# 165        177      Impact
#
#                                                                                                    Text2  \
# 0    To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 1    To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 2    Anake Kū is my Kumu. I have looked up to her and have followed along in her mission and in her v...
# 3                         I enjoyed the keynote because it was informational and felt really welcoming.
# 4     That Ku is a force in and of herself and changes and adapts with the times and circumstances. I...
# 5    Kū Kahakalau shared her manaʻo of where she was born and raised and her ability to speak several...
# 6                                                            I loved her energy. Good start to the day!
# 7    The ongoing dedication to revive ʻōlelo Hawaii and Hawaiian culture based learning. The love she...
# 8                              The mana, energy, love, excitement, care, emanating from this presenter.
# 9    Kū Kahakalau is an inspiring speaker, she set a wonderful tone for the conference. Very interest...
# 10   Reinforcment that as a community, we have the resources and do not need "outside" influences to ...
# 11                                                How passionate we are is reflected in what we convey.
# 12                                                            Some new historical facts that I learned.
# 13   I loved how she helped support 'olelo Hawai'i in the school systems and I felt a sense of pride ...
# 14    What impacted me the most from this presentation was learning that our ancestors learned, taugh...
# 15                                                                             She is so knowledgeable.
# 16   I enjoy learning from Dr. Kahakalau. In addition to her wealth of knowledge on indigenous educat...
# 17                                          Teach Hawaii-centric! Rigor! Connection to aina and kupuna!
# 18                                                                                     Great presenter.
# 19   Joining together on both sides of the fence. The systematic racism that has happened and continu...
# 20    It gave me a some of the history of the program and having a live reaction during the presentat...
# 21   The shared ideal of the importance of ʻŌlelo Hawaiʻi, the connection of Hawaiian values, morals,...
# 22   Data confirms that the lower education achievement of Native Hawaiians is a reflection of the in...
# 23   The fun, interactive style kept attendees on their toes and having to actually evaluate their op...
# 24    How educationally advanced Hawaii was in the past. Also PEAR DECK was amazing and I downloaded ...
# 25                                                                           Her passion and knowledge.
# 26                        Dr. Ku is amazing. Her presentation about history and knowledge blew me away.
# 27                                                                      Indigenous teaching is awesome!
# 28    The information on historical education in Hawaiʻi and how we should move forward with HCBE. Th...
# 29    The way Kū Kahakalau shared her ʻike and created an opportunity for everyone to participate and...
# ..                                                                                                   ...
# 136                                                       So much knowledge!!! Would love to hear more!
# 137  Although I have taken classes with 'Anakē Kū, I did not know how rare and prized the artistic ab...
# 138                                       Pedagogy of Aloha...I wouldn't mind learning more about that.
# 139   I love the quote that Anake Ku shared from Queen Liliu'okalani,"Never cease to act because you ...
# 140                                                                        She spoke with such passion!
# 141                                                                     I work at Kanu, it is personal.
# 142                                                                                         Everything.
# 143                                        So knowledgeable, so approachable, so inclusive... love her.
# 144               To know that our kūpuna was already doing what the modern world is teaching nowadays.
# 145                                                                                     Powerful mana'o
# 146                                                                                             Maikaʻi
# 147  She stated when students feel safe, when they feel like the people around them care for them...t...
# 148                                                                    His reasoning for his education.
# 149                                                                        All information was valuable
# 150                               Very inspirational. Pedagogy of Aloha. Relationship, Relevance, Rigor
# 151  Dr. kahakalau's use of "from womb to tomb" is so relevant is so many ways. It really resonated w...
# 152                             Holding ourselves accountable towards bettering the future for Hawaiians
# 153  Hearing that we were one of the lowest educated people. We were told that we werenʻt smart and t...
# 154  The factual history lesson was awesome. I had some knowledge of this history but his presentatio...
# 155   I will start to change the way I refer to "cultural vs. academic" and will now use the words "t...
# 156                                                                The importance of Hawaiian Education
# 157                                                                                         Rigor + Fun
# 158                                                             aloha ʻāina is a truly remarkable cycle
# 159                                  Kū's manaʻo, sharing genealogies and the interaction on the slides
# 160                                                                                  The aloha and mana
# 161                                                           Everything she spoke on was so impactful.
# 162                        It reminded me that we all are able to impact using our individual strengths
# 163    The insights into the way things were done long ago are being overlooked by mainstream education
# 164                                                                          Not letting the ship sink!
# 165  Dr. Kahakalau allows her audience "to play along", thus making the presentation relevant. She al...
#
#                                                                                          body_text_clean  \
# 0    To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 1    To meet someone with the knowledge and passion for Hawaii is inspirational and gave me a deeper ...
# 2    Anake Kū is my Kumu I have looked up to her and have followed along in her mission and in her vi...
# 3                          I enjoyed the keynote because it was informational and felt really welcoming
# 4     That Ku is a force in and of herself and changes and adapts with the times and circumstances I ...
# 5    Kū Kahakalau shared her manaʻo of where she was born and raised and her ability to speak several...
# 6                                                              I loved her energy Good start to the day
# 7    The ongoing dedication to revive ʻōlelo Hawaii and Hawaiian culture based learning The love she ...
# 155   i will start to chang the way i refer to cultur vs academ and will now use the word tradit and ...
# 156                                                                         the import of hawaiian educ
# 157                                                                                           rigor fun
# 158                                                                  aloha ʻāina is a truli remark cycl
# 159                                              kū manaʻo share genealog and the interact on the slide
# 160                                                                                  the aloha and mana
# 161                                                                   everyth she spoke on wa so impact
# 162                                it remind me that we all are abl to impact use our individu strength
# 163                the insight into the way thing were done long ago are be overlook by mainstream educ
# 164                                                                               not let the ship sink
# 165   dr kahakalau allow her audienc to play along thu make the present relev she alway uplift the lāhui
#
#      polarity  subjectivity TextBlob_Analysis
# 0    0.333333      0.533333          Positive
# 1    0.333333      0.533333          Positive
# 2    0.175000      0.375000          Positive
# 3    0.350000      0.450000          Positive
# 4    0.616667      0.741667          Positive
# 5    0.470000      0.490000          Positive
# 6    0.700000      0.700000          Positive
# 7    0.250000      0.362500          Positive
# 8    0.500000      0.600000          Positive
# 9    0.716667      0.883333          Positive
# 10   0.000000      0.050000           Neutral
# 11  -0.050000      0.850000          Negative
# 12   0.068182      0.227273          Positive
# 13   0.700000      0.800000          Positive
# 14   0.228889      0.251111          Positive
# 15   0.000000      0.000000           Neutral
# 16   0.370000      0.410000          Positive
# 17   0.000000      0.000000           Neutral
# 18   0.800000      0.750000          Positive
# 19   0.000000      0.000000           Neutral
# 20   0.136364      0.500000          Positive
# 21   0.400000      0.580000          Positive
# 22   0.050000      0.250000          Positive
# 23   0.150000      0.150000          Positive
# 24   0.250000      0.562857          Positive
# 25   0.000000      0.000000           Neutral
# 26   0.600000      0.900000          Positive
# 27   1.000000      1.000000          Positive
# 28   0.000000      0.000000           Neutral
# 29   0.675000      0.900000          Positive
# ..        ...           ...               ...
# 136  0.400000      0.433333          Positive
# 137  0.297436      0.573077          Positive
# 138  0.500000      0.500000          Positive
# 139  0.000000      0.450000           Neutral
# 140  0.000000      0.500000           Neutral
# 141  0.000000      0.300000           Neutral
# 142  0.000000      0.000000           Neutral
# 143  0.500000      0.600000          Positive
# 144  0.200000      0.300000          Positive
# 145  0.300000      1.000000          Positive
# 146  0.000000      0.000000           Neutral
# 147  0.203125      0.500000          Positive
# 148  0.000000      0.000000           Neutral
# 149  0.000000      0.000000           Neutral
# 150  0.650000      1.000000          Positive
# 151  0.366667      0.533333          Positive
# 152  0.000000      0.125000           Neutral
# 153  0.029762      0.339286          Positive
# 154  0.396429      0.796429          Positive
# 155  0.161111      0.406944          Positive
# 156  0.000000      0.000000           Neutral
# 157  0.300000      0.200000          Positive
# 158  0.750000      0.750000          Positive
# 159  0.000000      0.000000           Neutral
# 160  0.000000      0.000000           Neutral
# 161  0.000000      0.000000           Neutral
# 162  0.250000      0.512500          Positive
# 163 -0.050000      0.400000          Negative
# 164  0.000000      0.000000           Neutral
# 165  0.400000      0.900000          Positive
#
# [166 rows x 8 columns]

# %%
plt.bar(data['TextBlob_Analysis'].value_counts().index,
        data['TextBlob_Analysis'].value_counts())
# Out:
# <BarContainer object of 3 artists>

# %%
# Number of characters present in each text
data['Text2'].str.len().hist()

# %%
#Number of words in each text
data['Text2'].str.split().\
    map(lambda x: len(x)).\
    hist()

# %%
# Code Snippet for Word Number Histogram

def plot_word_number_histogram(text):
    text.str.split().\
        map(lambda x: len(x)).\
        hist()

# %%
plot_word_number_histogram(data['body_text_clean'])

# %%
#Average word length
data['Text2'].str.split().\
   apply(lambda x : [len(i) for i in x]). \
   map(lambda x: np.mean(x)).hist()

# %%
import nltk 
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sumat\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop = set(stopwords.words('english'))

# %%
corpus=[]
new= data['Text2'].str.split()
new=new.values.tolist()
corpus=[word for i in new for word in i]

from collections import defaultdict
dic=defaultdict(int)
for word in corpus:
    if word in stop:
        dic[word]+=1

# %%
def plot_top_stopwords_barchart(text):
    stop=set(stopwords.words('english'))
    
    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]
    from collections import defaultdict
    dic=defaultdict(int)
    for word in corpus:
        if word in stop:
            dic[word]+=1
            
    top=sorted(dic.items(), key=lambda x:x[1],reverse=True)[:10] 
    x,y=zip(*top)
    plt.bar(x,y)

# %%
plot_top_stopwords_barchart(data['Text2'])

# %%
from nltk.corpus import stopwords
from collections import  Counter

def plot_top_non_stopwords_barchart(text):
    stop=set(stopwords.words('english'))
    
    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    counter=Counter(corpus)
    most=counter.most_common()
    x, y=[], []
    for word,count in most[:40]:
        if (word not in stop):
            x.append(word)
            y.append(count)
            
    sns.barplot(x=y,y=x)

# %%
plot_top_non_stopwords_barchart(data['Text2'])

# %%
from nltk.util import ngrams
list(ngrams(['I' ,'went','to','the','river','bank'],2))
# Out:
# [('I', 'went'),
#  ('went', 'to'),
#  ('to', 'the'),
#  ('the', 'river'),
#  ('river', 'bank')]

# %%
#build a representation of vocabulary
from sklearn.feature_extraction.text import CountVectorizer
from collections import  Counter

def plot_top_ngrams_barchart(text, n=2):
    stop=set(stopwords.words('english'))

    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    def _get_top_ngram(corpus, n=None):
        vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
        bag_of_words = vec.transform(corpus)
        sum_words = bag_of_words.sum(axis=0) 
        words_freq = [(word, sum_words[0, idx]) 
                      for word, idx in vec.vocabulary_.items()]
        words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
        return words_freq[:10]

    top_n_bigrams=_get_top_ngram(text,n)[:10]
    x,y=map(list,zip(*top_n_bigrams))
    sns.barplot(x=y,y=x)

# %%
plot_top_ngrams_barchart(data['Text2'],2)

# %%
plot_top_ngrams_barchart(data['Text2'],3)

# %%
import matplotlib.pyplot as plt
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud, STOPWORDS
import nltk

def plot_wordcloud(text):
    nltk.download('stopwords')
    stop=set(stopwords.words('english'))

    def _preprocess_text(text):
        corpus=[]
        stem=PorterStemmer()
        lem=WordNetLemmatizer()
        for data in text:
            words=[w for w in word_tokenize(data) if (w not in stop)]

            words=[lem.lemmatize(w) for w in words if len(w)>2]

            corpus.append(words)
        return corpus
    
    corpus=_preprocess_text(text)
    
    wordcloud = WordCloud(
        background_color='white',
        stopwords=set(STOPWORDS),
        max_words=100,
        max_font_size=30, 
        scale=3,
        random_state=1)
    
    wordcloud=wordcloud.generate(str(corpus))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
 
    plt.imshow(wordcloud)
    plt.show()

# %%
plot_wordcloud(data['Text2'])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sumat\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def clean_tweet(tweet): 
    ''' 
    Utility function to clean tweet text by removing links, special characters 
    using simple regex statements. 
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

# %%
def get_sentiment(text): 
    ''' 
    Utility function to classify sentiment of passed tweet 
    using textblob's sentiment method 
    '''
    # create TextBlob object of passed tweet text 
    analysis = TextBlob(text)
    # set sentiment 
    if analysis.sentiment.polarity > 0: 
        return 'positive'
    elif analysis.sentiment.polarity == 0: 
        return 'neutral'
    else: 
        return 'negative'

# %%
from pprint import pprint

stweet = get_sentiment(data['body_text_clean'][3])
ctweet = clean_tweet (data['body_text_clean'][3])
#pprint("Sentiment {} - Text {} ".format(stweet))
pprint(ctweet)

# %%
#plt.rcParams['figure.figsize'] = [10, 8]

#for index, comedian in enumerate(data.index):
x = data.polarity
y = data.subjectivity
plt.scatter(x, y, color='red')
#plt.text(x+.001, y+.001, data['text'])
plt.xlim(-.3, .6) 
plt.ylim(ymin=-.2, ymax=.3)
plt.title('Sentiment Analysis')
plt.xlabel('<-Negative ------Positive->')
plt.ylabel('<-- Facts --------Opinions -->')

plt.show()

# %%
# Split each routine into 10 parts
import numpy as np
import math

def split_text(text, n=6):
    '''Takes in a string of text and splits into n equal parts, with a default of 10 equal parts.'''

    # Calculate length of text, the size of each chunk of text and the starting points of each chunk of text
    length = len(text)
    size = math.floor(length / n)
    start = np.arange(0, length, size)
    
    # Pull out equally sized pieces of text and put it into a list
    split_list = []
    for piece in range(n):
        split_list.append(text[start[piece]:start[piece]+size])
    return split_list

# %%
data

# %%
list_pieces = []
for t in data.Text2:
    split = split_text(t)
    list_pieces.append(split)
    
list_pieces

# %%
len(list_pieces)

# %%
len(list_pieces[0])

# %%
polarity_transcript = []
for lp in list_pieces:
    polarity_piece = []
    for p in lp:
        polarity_piece.append(TextBlob(p).sentiment.polarity)
    polarity_transcript.append(polarity_piece)
    
polarity_transcript

# %%
plt.plot(polarity_transcript[0])
plt.plot(np.arange(0,6), np.zeros(6))
#plt.title(data['text'].index[1])
plt.ylim(ymin=-.2, ymax=.3)
plt.xlabel('<-Feedback comments->',fontsize=12)
plt.ylabel('<-Negative ------Positive->',fontsize=12)
plt.show()

# %%
#plt.subplot(3, 4, index+1)
plt.plot(polarity_transcript)
plt.plot(np.arange(0,10), np.zeros(10))
plt.title(data['text'])
plt.ylim(ymin=-.2, ymax=.3)
    
plt.show()
